# %%
import pandas as pd
import numpy as np

# %%
dat = pd.read_excel("./data/test_reshape.xlsx")

# %%
dat
# Out:
#    ID       Name  gp1_a  gp1_b  gp1_c  gp2_x  gp2_y
# 0   1       Alex    1.0    NaN    NaN    NaN    NaN
# 1   2        Bob    NaN    NaN    1.0    NaN    NaN
# 2   3  Catherine    NaN    1.0    1.0    NaN    NaN
# 3   4       Dave    1.0    NaN    NaN    1.0    NaN
# 4   5     Edward    NaN    NaN    NaN    NaN    1.0

# %%
tidy = pd.melt(dat, id_vars=['ID', 'Name'], var_name="class", value_name="value").dropna(subset=['value'])
tidy.sort_values(by=['ID'])
# Out:
#     ID       Name  class  value
# 0    1       Alex  gp1_a    1.0
# 11   2        Bob  gp1_c    1.0
# 7    3  Catherine  gp1_b    1.0
# 12   3  Catherine  gp1_c    1.0
# 3    4       Dave  gp1_a    1.0
# 18   4       Dave  gp2_x    1.0
# 24   5     Edward  gp2_y    1.0

# %%
tidy['group'] = tidy['class'].apply(lambda s: s[:3])
tidy['subclass'] = tidy['class'].map(lambda s: s[-1:])
tidy.sort_values(by='ID')
# Out:
#     ID       Name  class  value group subclass
# 0    1       Alex  gp1_a    1.0   gp1        a
# 11   2        Bob  gp1_c    1.0   gp1        c
# 7    3  Catherine  gp1_b    1.0   gp1        b
# 12   3  Catherine  gp1_c    1.0   gp1        c
# 3    4       Dave  gp1_a    1.0   gp1        a
# 18   4       Dave  gp2_x    1.0   gp2        x
# 24   5     Edward  gp2_y    1.0   gp2        y

# %%
tidy = tidy.drop(columns=['class', 'value'])

# %%
tidy
# Out:
#     ID       Name group subclass
# 0    1       Alex   gp1        a
# 3    4       Dave   gp1        a
# 7    3  Catherine   gp1        b
# 11   2        Bob   gp1        c
# 12   3  Catherine   gp1        c
# 18   4       Dave   gp2        x
# 24   5     Edward   gp2        y

# %%
tidy1 = tidy.groupby(['ID','Name']).apply(pd.DataFrame.pivot,
                              # index=None,
                              columns='group',
                              values='subclass')
tidy1
# Out:
#                  gp1  gp2
# ID Name
# 1  Alex      0     a  NaN
# 2  Bob       11    c  NaN
# 3  Catherine 7     b  NaN
#              12    c  NaN
# 4  Dave      3     a  NaN
#              18  NaN    x
# 5  Edward    24  NaN    y

# %%
tidy1.reset_index(inplace=True)
tidy2 = tidy1.drop(columns='level_2')
tidy2
# Out:
#    ID       Name  gp1  gp2
# 0   1       Alex    a  NaN
# 1   2        Bob    c  NaN
# 2   3  Catherine    b  NaN
# 3   3  Catherine    c  NaN
# 4   4       Dave    a  NaN
# 5   4       Dave  NaN    x
# 6   5     Edward  NaN    y

# %%
tidy2.dtypes
# Out:
# ID       int64
# Name    object
# gp1     object
# gp2     object
# dtype: object

# %%
'a'.join('bb')
# Out:
# 'bab'

# %%
# tidy3 = tidy2.groupby(['ID', 'Name'])['gp1'].apply(','.join).reset_index()
tidy3 = tidy2.groupby(['ID', 'Name'])['gp1'].apply(','.join)
tidy3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-4da817e23dc2> in <module>()
#       1 # tidy3 = tidy2.groupby(['ID', 'Name'])['gp1'].apply(','.join).reset_index()
# ----> 2 tidy3 = tidy2.groupby(['ID', 'Name'])['gp1'].dropna(subset=['gp1']).apply(','.join)
#       3 tidy3
#
# ~\AppData\Local\conda\conda\envs\dswork\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\AppData\Local\conda\conda\envs\dswork\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'dropna' of 'SeriesGroupBy' objects, try using the 'apply' method

# %% [markdown]
# **Reference:**
# - https://www.ibm.com/developerworks/community/blogs/jfp/entry/Tidy_Data_In_Python?lang=en
